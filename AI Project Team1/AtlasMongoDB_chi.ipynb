# %%
# !pip install pymongo[snappy,gssapi,srv,tls] #安裝相關套件，不理錯誤訊息
# !pip install pymongo
# Out:
# ...
#   Using cached https://files.pythonhosted.org/packages/9a/b8/1ec56b6fa8a2e2a81420bd3d90e70b59fc83f6b857fb2c2c37accddc8be3/pykerberos-1.2.1.tar.gz
# ...
#   Using cached https://files.pythonhosted.org/packages/45/35/65d9f8cc537129894b4b32647d80212d1fa342877581c5b8a69872cea8be/python-snappy-0.5.4.tar.gz
# ...
#   ERROR: Failed building wheel for pykerberos
#   Running setup.py clean for pykerberos
# ...
#   ERROR: Failed building wheel for python-snappy
#   Running setup.py clean for python-snappy
# Failed to build pykerberos python-snappy
# ...
#     Running setup.py install for pykerberos ... error
# ...

# %%
# Database說明:
# 先申請 MongoDB Cloud 與 GCP 合作的雲端 Database，免費容量 512MB
# python MongoDB : https://www.w3school.com.cn/python/python_mongodb_find.asp

# %%
from pymongo import MongoClient

# %%
# 登入方式
#client = MongoClient('mongodb+srv://Harvey:wu060606@harvey-xruq5.gcp.mongodb.net/News?retryWrites=true&w=majority')
client = MongoClient("mongodb+srv://nier:1112@ai02-zwv1w.gcp.mongodb.net/AI02?retryWrites=true&w=majority")

# %%
db = client["project_phone"]   # 選擇資料庫，預先創立 project_phone
collection = db["ptt_iphone"]  # 選擇 collection (類似table)，預先創立
collection
# Out:
# Collection(Database(MongoClient(host=['ai02-shard-00-02-zwv1w.gcp.mongodb.net:27017', 'ai02-shard-00-01-zwv1w.gcp.mongodb.net:27017', 'ai02-shard-00-00-zwv1w.gcp.mongodb.net:27017'], document_class=dict, tz_aware=False, connect=True, retrywrites=True, w='majority', authsource='admin', replicaset='AI02-shard-0', ssl=True), 'project_phone'), 'ptt_iphone')

# %%
# 讀取 json 檔案
import json
with open("./drive/My Drive/機不可失/手機型號資料彙整/ptt_iphone.json", mode="r", encoding="utf-8") as f:
  ptt_iphone = json.load(f)
print(ptt_iphone)
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %%
# 將資料寫入 project_phone 資料庫裡面的 ptt_iphone collection(table)內
collection.insert_many(ptt_iphone)

# %%
# 找 Name: iphone5c 的資料
for i in collection.find({"Name": "iphone_5c"}):
  print(i)
print(type(i))
# Out:
# {'_id': ObjectId('5ee6dee8c3a31d6ff17d9d3a'), 'Name': 'iphone_5c', 'durability': ['對於封閉系統真的用不習慣', '電池勒，是報多少', 'iPad3290iPhone2590好像是這樣', '我都想把4S拿去維修一下了', '請教各位先進，其他損壞是什麼意思，如果整支手機', '除了螢幕之外都壞光光了，也只要付其他損壞那一排', '的維修費用嗎？', '如果2590那街邊修理店會死一堆', '換電池民間才600為何死一堆？', '阿倫：', '600塊用的是被qc打下來的電池', '可以考慮iPhone8了~', '私人維修死一堆', '600的淘寶電池爛，而且換完就沒防水，稍微好一點的1', '200.1300但一樣不是原廠的也會失去防水更沒有90天', '保固', '民間維修超爛...錢太多才會去', '動到螢幕的一堆裝回去還會漏光有隙縫', '一堆說的好像台灣技術比中國爛zzzz', '民間維修明明也一堆品質好的只是打不過品質差的', '所以品質好的要花多少?', '笑死喔台灣比國外貴', '感謝示範台灣人的問法', '7、7+沒快充，電池不到一年就要換了？', '怎沒回應了', '4s的wifi反灰問題和藍芽一直轉圈圈不知道還有沒有', '救', '4S其他損壞─新台幣6590元換機吧', '唉..終於不用被代理荼毒惹', '可以直接拿錢給蘋果賺就是潮', '這價錢跟本在表神腦', '好貴', '不噓，但是就算以中位數來看，台灣是4萬，日本年輕', '人有9萬台幣，歐洲應該也很高吧？', 'ipad的維修價不如直接買新的', '我怎麼記得最近台幣算是強勢、美元日幣都走弱~', '最好蘋果會讓供應商把被打下來的電池拿出來賣', '這樣，叫那些黑心的維修商怎麼活下去？', '果然是9/9', '用Edge看看好了', '又要重新定義東西了嗎', '重新定義1200萬畫素', '重新定義2GBRAM', '永遠落後安卓，可悲', '要起飛去外太空了嗎', '有呀，歷代銷量屌虐各家安卓機QQ', '四樓別這樣爽爽賺錢沒落後別人才是最重要的', '落後賣的比安濁好就好啊', '阿還有利潤', '推出4吋機種我就買', '潮，你不會看到他印Apple，而是的圖案', '4F崩潰了',
# ...

# %%
# insert_one 存入單個, insert([test, test1]) 存入多個
test = {
    
    "Name":"nezuko",
    "age":23
}

test1 = {
    
    "Name":"nier",
    "age":80
}

#collection_currency.insert_one(test)
#collection_currency.insert_one(test1) # .insert_one一次插入一份字典
#collection_currency.insert([test, test1])

# %% [markdown]
# ## 此圖為GCP平台上的GUI，可看到方才存入的資料
# ![Image of Yaktocat](https://i.imgur.com/OSJpAgM.jpg)

# %%
# 使用 GUI : Robo 3T，更簡單、方便
# 下載地址 : https://robomongo.org/download ， 下載後 Next 到底，以下跟著步驟做，有看到資料庫 "News"就成功了
# address 的部分，找 overview region 底下的 primary

# %% [markdown]
# ## 1. 點選 "Create"
# ![Image of Yaktocat](https://i.imgur.com/wdM6IWn.jpg)

# %% [markdown]
# ## 2. Connection :
# ### ai02-shard-00-02-zwv1w.gcp.mongodb.net
# ![Image of Yaktocat](https://i.imgur.com/7ikwhRG.jpg)
# ![Image of Yaktocat](https://i.imgur.com/PMamZXo.jpg)

# %% [markdown]
# ## 3. Authentication :
# ### admin : 有所有資料庫的控制權
# ### User Name : nier
# ### Password : 1112
# #### 以上為GCP平台中創建的使用者帳號，隨然不會存機密資料，但要養成保密的好習慣!
# ![Image of Yaktocat](https://i.imgur.com/kyZoJRX.jpg)

# %% [markdown]
# ### 4. SSL
# ![Image of Yaktocat](https://i.imgur.com/Q2q1i0C.jpg)

# %% [markdown]
# ### 5. Advanced
# ### 指定預設資料庫，可不填
# ![Image of Yaktocat](https://i.imgur.com/SiyixNt.jpg)
